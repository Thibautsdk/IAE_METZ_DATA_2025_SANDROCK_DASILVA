# %% [markdown]
# <a href="https://colab.research.google.com/github/Thibautsdk/IAE_METZ_DATA_2025_SANDROCK_DASILVA/blob/main/TD_DATA4FUNDS_ANTHO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Premier code python par AnthoBorse pour le cours de l'Iae METZ
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# #Simple Example

# %%
prenom = "Elias" #variable gardé dans une instance temporaire et string c'est du texte
salaire = 57000 # integer sont les chiffres entier naturels
height = 1.70 #loats chiffres à virgules

# %%
print("prenom")
# Out:
# prenom

# %%
print(f"On dirait que {prenom} est seul, il gagne {salaire} roubles ")
# Out:
# On dirait que Elias est seul, il gagne 57000 roubles

# %%
# Arithmetic
valeur_1 = 10
valeur_2 = 3

a = 10
b = 3

# %%
a, b = 10, 3

# %%
print(f"SUM: {a + b}, Differences: {a - b}, Product{a * b}, Division {a / b}")
# Out:
# SUM: 13, Differences: 7, Product30, Division 3.3333333333333335

# %%
print(f"Division Integer: { a // b}, Modulos: {a % b}, exponentiel: { a ** b}")
# Out:
# Division Integer: 3, Modulos: 1, exponentiel: 1000

# %%
# LIST
stocks = ["Apple", "bananes", "fraises"]
stocks[0] # 0 car en informatique on ne commnence pas à 1.
# Out:
# 'Apple'

# %%
# DICTIONNAIRES
# Non-ordonné et paires clé-valeur. Uniques et immutables.
# Dans la vraie vie, qu'utilisons le plus ?
eleve = {"nom": "FABIAN", "age": 25, "city": "DUSSELDORF" }
print(f"Salut je suis {eleve['nom']} et j'ai {eleve['age']} ans, je viens de {eleve['city']}")
# Out:
# Salut je suis FABIAN et j'ai 25 ans, je viens de DUSSELDORF

# %%
# La façon la plus courante de stocker des données en python est via unu DATAFRAME.
# DATA + FRAME
# PACKAGE
import pandas as pd

data = pd.DataFrame({'Data':['2020-01-01','2025-02-11'], 'FondInvestLux':[10, 100], 'Amundi':[11,13]})

# %%
data #pas besoin de mettre print car cela n'est pas une variable mais une dataframe directement.
# Out:
#          Data  FondInvestLux  Amundi
# 0  2020-01-01             10      11
# 1  2025-02-11            100      13
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['FondInvestLux'].plot(kind='hist', bins=20, title='FondInvestLux')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['Amundi'].plot(kind='hist', bins=20, title='Amundi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# data.groupby('Data').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
# Fonctions et boucles basiques à connaître
note = 10
if note > 10:
  print("J'ai plus que la moyenne")
elif note <10:
  print("j'ai pas la moyenne")
else: # il faut savoir cloturer certaines boucles, #else = sinon
  print("j'ai pile la moyenne")
# Out:
# j'ai pile la moyenne

# %%
x = int(input("Entres un chiffre"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-0e0ba5f8b177> in <cell line: 0>()
# ----> 1 x = int(input("Entres un chiffre"))
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
# ...

# %%
note = float(input("Entres un chiffre"))

# %%
for i in range(3)
  print(f"Boucle avec x iterations de {i}")
# Out:
#   File "<ipython-input-32-bb110dc1b1c7>", line 1
#     for i in range(3)
#                      ^
# SyntaxError: expected ':'

# %%
# Boucle plus complexe: WHILE qui est une boucle conditionnelle
count = 0

# %%
while count < 3:
  print(f"Count: {4}")
  count +=1
# Out:
# Count: 4
# Count: 4
# Count: 4

# %%
# LES BASES des FONCTIONS
def greet(nom, greeting = "Hello"): #nom et greeting sont les 2 paramètres
  return f"{greeting}, {nom} !!!"
print(greet("Jade"))
print(greet("Yassine","BONJOUR"))
# Out:
# Hello, Jade !!!
# BONJOUR, Yassine !!!
